# %% [markdown]
# # *Python* Data Science introdução

# %% [markdown]
# ## Pacotes

# %%
import random as rnd
import numpy as np

# %% [markdown]
# ## Operações básicas

# %%
2+2
# Out:
# 4

# %%
4-3
# Out:
# 1

# %%
5*32
# Out:
# 160

# %%
76/21
# Out:
# 3.619047619047619

# %%
4**4
# Out:
# 256

# %% [markdown]
# ## Funções

# %%
def minha_fun_potencia(x, potencia):

  return x**potencia

# %%
minha_fun_potencia(2,4)
# Out:
# 16

# %% [markdown]
# ## Criação de vetores/listas

# %%
vetor1 = [1, 5, 7, 3, 8, 10]
vetor1
# Out:
# [1, 5, 7, 3, 8, 10]

# %%
vetor2 = list(range(6))
vetor2
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
rnd.seed(123)
vetor_aleatorio_0_1 = [round(rnd.uniform(0,1),4) for i in range(5)]
vetor_aleatorio_0_1
# Out:
# [0.0524, 0.0872, 0.4072, 0.1077, 0.9012]

# %%
vetor_aleatorio_inteiros = rnd.sample(range(10,100), 5)
vetor_aleatorio_inteiros
# Out:
# [53, 16, 30, 27, 81]

# %% [markdown]
# ## Operações com vetores

# %%
np.array(vetor1)+np.array(vetor2)
# Out:
# array([ 1,  6,  9,  6, 12, 15])

# %%
np.array(vetor1)*np.array(vetor2)
# Out:
# array([ 0,  5, 14,  9, 32, 50])

# %% [markdown]
# ## Operações com matrizes

# %% [markdown]
# - Criar matriz

# %%
matrizA = np.array([[2,3], [1,4]])
matrizA
# Out:
# array([[2, 3],
#        [1, 4]])

# %%
matrizB = np.random.rand(2,2)
matrizB
# Out:
# array([[0.41148688, 0.44283629],
#        [0.35156835, 0.65167443]])

# %% [markdown]
# - Operações

# %%
matrizA+matrizB
# Out:
# array([[2.41148688, 3.44283629],
#        [1.35156835, 4.65167443]])

# %%
matrizA*matrizB
# Out:
# array([[0.82297377, 1.32850886],
#        [0.35156835, 2.60669771]])

# %%
matrizA.dot(matrizB)
# Out:
# array([[1.87767881, 2.84069586],
#        [1.81776028, 3.049534  ]])
