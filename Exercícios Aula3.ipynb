# %% [markdown]
# # **Lista de Exercícios para ser realizados em aula**
#
#
#
#
# 1.   Crie uma lista com 10 nomes e faça uma função que retorne a quantidade de caracteres de cada nome e o nome.
#
# **Os Exercícios abaixo devem ser realizados no dataset Scout.**
#
# 2.   Crie um filtro que traga apenas jogadores meio de campo.
#
# 3.   Crie um filtro que traga apenas jogadores com mais de 25 anos.
#
# 4.   Apresente os 10 jogadores com maior pontuação quantidade de impedimentos
#
# 5.   Quais times estão com maior pontuação no campeonato?
#
# 6.   Quais atacantes tem maior valor de mercado (preco_num)?
#
# 7.   Crie estatísticas de jogadores por posição, incluido o valor de mercado.
#
# 8.   Qual a média de pontos por jogo por clube?
